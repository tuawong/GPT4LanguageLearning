# %%
from main import Constants
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from main import Constants
#
# ImportError: cannot import name 'Constants' from 'main' (c:\Users\wongs\Repo\GPT4LanguageLearning\main\__init__.py)
