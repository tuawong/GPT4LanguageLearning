# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, DateTime, func
from sqlalchemy.orm import declarative_base

# %%
df = pd.read_csv("data/MandarinWordList.csv")
df.columns = [col.lower().replace(" ", "_") for col in df.columns]

# %%
df
# Out:
#       word_id word      pinyin pinyin_simplified       type word_category  \
# 0     D000001   帮助  bang1 zhu4        bang1 zhu4  Noun/Verb       Support
# 1     D000002   包裹   bao1 guo3         bao1 guo3       Noun        Object
# 2     D000004   不错    bu2 cuo4          bu2 cuo4  Adjective       Opinion
# 3     D000005   不过    bu2 guo4          bu2 guo4    Grammar       Grammar
# 4     D000006   不太    bu2 tai4          bu2 tai4   Adjuster        Degree
# ...       ...  ...         ...               ...        ...           ...
# 1898  D002641    省       shěng            sheng3       Noun     Geography
# 1899  D002642    省       shěng            sheng3       Verb        Action
# 1900  D002643   挑战   tiǎo zhàn       tiao3 zhan4  Noun/Verb        Action
# 1901  D002644  艺术品  yì shù pǐn     yi4 shu4 pin3       Noun           Art
# 1902  D002645   优秀     yōu xiù         you1 xiu4  Adjective   Description
#
#      word_rarity                                            meaning  \
# ...

# %%
# Base class for declaring your table models
Base = declarative_base()

class WordEntry(Base):
    __tablename__ = "word_entries"  # this is the table name in the DB

    id = Column(Integer, primary_key=True, index=True)
    word = Column(String, nullable=False)
    meaning = Column(String)
    example = Column(String)
    added_at = Column(DateTime(timezone=True), server_default=func.now())

# %%
import pandas as pd
from sqlalchemy import create_engine
from models import Base, WordEntry

# Connect to SQLite (use same DB path as your Dash app)
engine = create_engine("sqlite:///mydata.db")

# 1. Create the table if it doesn't exist
Base.metadata.create_all(bind=engine)

# 2. Read CSV
df = pd.read_csv("chinese_words.csv")

# 3. Clean/rename columns if necessary
df = df.rename(columns={
    "Word": "word",
    "Meaning": "meaning",
    "Example": "example"
})

# 4. Insert into DB
df.to_sql("word_entries", con=engine, if_exists="append", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
#       2 from sqlalchemy import create_engine
# ----> 3 from models import Base, WordEntry
#       5 # Connect to SQLite (use same DB path as your Dash app)
#       6 engine = create_engine("sqlite:///mydata.db")
#
# ModuleNotFoundError: No module named 'models'
