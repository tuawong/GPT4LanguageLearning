# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, DateTime, func
from sqlalchemy.orm import declarative_base
from sqlalchemy import inspect

# %%
from database import Base, SessionLocal, engine, ensure_views_from_files, init_db

# %%
from main.gsheets import load_dict
import main.Constants as Constants

dict_sheet_name = Constants.RESPONSE_LOG_SHEET_NAME
gsheet_name = Constants.SHEET_NAME

response_log = load_dict(gsheet_mode=True, gsheet_name=gsheet_name, worksheet_name=dict_sheet_name)
response_log.columns = [col.lower().replace(' ', '_') for col in response_log.columns]

# %%
response_log.to_sql('ResponseLog', con=engine, if_exists='append', index=False)
# Out:
# 28

# %%
responselog_sql = pd.read_sql("""
                 SELECT *
                 FROM ResponseLog
                 """, engine)

responselog_sql
# Out:
# Empty DataFrame
# Columns: [quiz_id, prompt, prompt_pinyin, prompt_meaning, response, response_pinyin, response_meaning, correctness, naturalness, contextual_appropriateness, comment, complexity, tone]
# Index: []

# %%
df = pd.read_sql("""
                 SELECT 
                    WordDict.*, 
                    IIF(num_quiz_attempt IS NULL, 0, num_quiz_attempt) AS num_quiz_attempt,
                    IIF(pinyin_correct_cnt IS NULL, 0, pinyin_correct_cnt) AS pinyin_correct_cnt,
                    IIF(meaning_correct_cnt IS NULL, 0, meaning_correct_cnt) AS meaning_correct_cnt, 
                    last_quiz
                 FROM WordDict
                 LEFT JOIN QuizScore ON (WordDict.word_id = QuizScore.word_id) AND (WordDict.word = QuizScore.word)
                 """, engine)

# %%
rename_dict = {'word_id': 'Word Id',
 'word': 'Word',
 'pinyin': 'Pinyin',
 'pinyin_simplified': 'Pinyin Simplified',
 'type': 'Type',
 'word_category': 'Word Category',
 'word_rarity': 'Word Rarity',
 'meaning': 'Meaning',
 'sentence': 'Sentence',
 'sentence_pinyin': 'Sentence Pinyin',
 'sentence_meaning': 'Sentence Meaning',
 'added_date': 'Added Date',
 'num_quiz_attempt': 'Quiz Attempts',
 'pinyin_correct_cnt': 'Num Pinyin Correct',
 'meaning_correct_cnt': 'Num Meaning Correct',
 'last_quiz': 'Last Quiz'}

df = df.rename(columns=rename_dict)

# %%
df
# Out:
#       Word Id Word      Pinyin Pinyin Simplified       Type Word Category  \
# 0     D000001   帮助  bang1 zhu4        bang1 zhu4  Noun/Verb       Support
# 1     D000002   包裹   bao1 guo3         bao1 guo3       Noun        Object
# 2     D000004   不错    bu2 cuo4          bu2 cuo4  Adjective       Opinion
# 3     D000005   不过    bu2 guo4          bu2 guo4    Grammar       Grammar
# 4     D000006   不太    bu2 tai4          bu2 tai4   Adjuster        Degree
# ...       ...  ...         ...               ...        ...           ...
# 1902  D002655   阳光  yáng guāng      yang2 guang1       Noun        Nature
# 1903  D002656   阳光  yáng guāng      yang2 guang1  Adjective     Character
# 1904  D002657   混蛋     hún dàn         hun2 dan4       Noun       Emotion
# 1905  D002658   动手   dòng shǒu       dong4 shou3       Verb        Action
# 1906  D002659   动手   dòng shǒu       dong4 shou3       Verb      Behavior
#
#      Word Rarity                                            Meaning  \
# 0         Common                                    Help/Assistance
# 1         Common                                            Package
# 2         Common                       Good (More positive than 还好)
# 3         Common         But (Similar to dan4 shi4 but less formal)
# 4         Common                                          not quite
# ...          ...                                                ...
# 1902      Common  Sunlight; the light or warmth that comes from ...
# 1903      Common  Optimistic or cheerful; having a bright and po...
# 1904      Common  A contemptible or despicable person; often use...
# 1905      Common  To start doing something; to begin a task or a...
# 1906      Common  To physically attack or hit someone; to use on...
#
#               Sentence                                    Sentence Pinyin  \
# 0           我可以帮助你学习中文                 Wǒ kěyǐ bāngzhù nǐ xuéxí Zhōngwén.
# 1          他昨天收到了一个包裹。                      Wǒ zuótiān shōudào le bāoguǒ.
# 2     这个电影不错，我们可以一起去看。       Zhè gè diànyǐng bùcuò wǒmen kěyǐ yìqǐ qù kàn
# 3     我喜欢这家餐厅，不过价格有点贵。  Wǒ xǐhuān zhè jiā cāntīng búguò jiàgé yǒudiǎn ...
# 4                  不太好                                      bu2 tai4 hao3
# ...                ...                                                ...
# 1902      阳光透过窗户洒在地板上。      Yángguāng tòuguò chuānghù sǎ zài dìbǎn shàng.
# 1903   她总是那么阳光，感染身边的人。  Tā zǒng shì nàme yángguāng, gǎnrǎn shēnbiān de...
# 1904     他真是个混蛋，居然骗了我。           Tā zhēn shì gè húndàn, jūrán piàn le wǒ.
# 1905  开始动手，我们还有很多工作要做。  Kāishǐ dòngshǒu, wǒmen hái yǒu hěn duō gōngzuò...
# 1906     他因为一点小事就动手打人。      Tā yīnwèi yīdiǎn xiǎoshì jiù dòngshǒu dǎ rén.
#
#                                        Sentence Meaning  \
# 0                         I can help you study Chinese.
# 1                     I received the package yesterday.
# 2     This movie is pretty good; we can go watch it ...
# 3     I like this restaurant but the price is a bit ...
# 4                                        not quite good
# ...                                                 ...
# 1902  Sunlight shines through the window onto the fl...
# 1903  She is always so cheerful, spreading positivit...
# 1904                 He's such a jerk for deceiving me.
# 1905    Let's get started, we have a lot of work to do.
# 1906           He hit someone just over a small matter.
#
#                       Added Date  Quiz Attempts  Num Pinyin Correct  \
# 0     2024-09-21 00:00:00.000000              0                   0
# 1     2024-09-21 00:00:00.000000              0                   0
# 2     2024-09-21 00:00:00.000000              0                   0
# 3     2024-09-21 00:00:00.000000              0                   0
# 4     2024-09-21 00:00:00.000000              0                   0
# ...                          ...            ...                 ...
# 1902  2025-08-17 00:00:00.000000              0                   0
# 1903  2025-08-17 00:00:00.000000              0                   0
# 1904  2025-08-17 00:00:00.000000              0                   0
# 1905  2025-08-17 00:00:00.000000              0                   0
# 1906  2025-08-17 00:00:00.000000              0                   0
#
#       Num Meaning Correct Last Quiz
# 0                       0      None
# 1                       0      None
# 2                       0      None
# 3                       0      None
# 4                       0      None
# ...                   ...       ...
# 1902                    0      None
# 1903                    0      None
# 1904                    0      None
# 1905                    0      None
# 1906                    0      None
#
# [1907 rows x 16 columns]

# %%
cols = ['Word Id', 'Word', 'Pinyin', 'Meaning', 'Added Date', 'Word Category', 'Word Rarity', 'Type', 'Sentence', 'Sentence Pinyin', 'Sentence Meaning', 'Quiz Attempts', 'Num Pinyin Correct', 'Num Meaning Correct', 'Last Quiz']
df[cols]
# Out:
#       Word Id Word      Pinyin  \
# 0     D000001   帮助  bang1 zhu4
# 1     D000002   包裹   bao1 guo3
# 2     D000004   不错    bu2 cuo4
# 3     D000005   不过    bu2 guo4
# 4     D000006   不太    bu2 tai4
# ...       ...  ...         ...
# 1902  D002655   阳光  yáng guāng
# 1903  D002656   阳光  yáng guāng
# 1904  D002657   混蛋     hún dàn
# 1905  D002658   动手   dòng shǒu
# 1906  D002659   动手   dòng shǒu
#
#                                                 Meaning  \
# 0                                       Help/Assistance
# 1                                               Package
# 2                          Good (More positive than 还好)
# 3            But (Similar to dan4 shi4 but less formal)
# 4                                             not quite
# ...                                                 ...
# 1902  Sunlight; the light or warmth that comes from ...
# 1903  Optimistic or cheerful; having a bright and po...
# 1904  A contemptible or despicable person; often use...
# 1905  To start doing something; to begin a task or a...
# 1906  To physically attack or hit someone; to use on...
#
#                       Added Date Word Category Word Rarity       Type  \
# 0     2024-09-21 00:00:00.000000       Support      Common  Noun/Verb
# 1     2024-09-21 00:00:00.000000        Object      Common       Noun
# 2     2024-09-21 00:00:00.000000       Opinion      Common  Adjective
# 3     2024-09-21 00:00:00.000000       Grammar      Common    Grammar
# 4     2024-09-21 00:00:00.000000        Degree      Common   Adjuster
# ...                          ...           ...         ...        ...
# 1902  2025-08-17 00:00:00.000000        Nature      Common       Noun
# 1903  2025-08-17 00:00:00.000000     Character      Common  Adjective
# 1904  2025-08-17 00:00:00.000000       Emotion      Common       Noun
# 1905  2025-08-17 00:00:00.000000        Action      Common       Verb
# 1906  2025-08-17 00:00:00.000000      Behavior      Common       Verb
#
#               Sentence                                    Sentence Pinyin  \
# 0           我可以帮助你学习中文                 Wǒ kěyǐ bāngzhù nǐ xuéxí Zhōngwén.
# 1          他昨天收到了一个包裹。                      Wǒ zuótiān shōudào le bāoguǒ.
# 2     这个电影不错，我们可以一起去看。       Zhè gè diànyǐng bùcuò wǒmen kěyǐ yìqǐ qù kàn
# 3     我喜欢这家餐厅，不过价格有点贵。  Wǒ xǐhuān zhè jiā cāntīng búguò jiàgé yǒudiǎn ...
# 4                  不太好                                      bu2 tai4 hao3
# ...                ...                                                ...
# 1902      阳光透过窗户洒在地板上。      Yángguāng tòuguò chuānghù sǎ zài dìbǎn shàng.
# 1903   她总是那么阳光，感染身边的人。  Tā zǒng shì nàme yángguāng, gǎnrǎn shēnbiān de...
# 1904     他真是个混蛋，居然骗了我。           Tā zhēn shì gè húndàn, jūrán piàn le wǒ.
# 1905  开始动手，我们还有很多工作要做。  Kāishǐ dòngshǒu, wǒmen hái yǒu hěn duō gōngzuò...
# 1906     他因为一点小事就动手打人。      Tā yīnwèi yīdiǎn xiǎoshì jiù dòngshǒu dǎ rén.
#
#                                        Sentence Meaning  Quiz Attempts  \
# 0                         I can help you study Chinese.              0
# 1                     I received the package yesterday.              0
# 2     This movie is pretty good; we can go watch it ...              0
# 3     I like this restaurant but the price is a bit ...              0
# 4                                        not quite good              0
# ...                                                 ...            ...
# 1902  Sunlight shines through the window onto the fl...              0
# 1903  She is always so cheerful, spreading positivit...              0
# 1904                 He's such a jerk for deceiving me.              0
# 1905    Let's get started, we have a lot of work to do.              0
# 1906           He hit someone just over a small matter.              0
#
#       Num Pinyin Correct  Num Meaning Correct Last Quiz
# 0                      0                    0      None
# 1                      0                    0      None
# 2                      0                    0      None
# 3                      0                    0      None
# 4                      0                    0      None
# ...                  ...                  ...       ...
# 1902                   0                    0      None
# 1903                   0                    0      None
# 1904                   0                    0      None
# 1905                   0                    0      None
# 1906                   0                    0      None
#
# [1907 rows x 15 columns]

# %%
phrase_df = pd.read_sql("""
                 SELECT *
                 FROM PhraseDict
                 """, engine)

rename_dict = {col:col.replace('_', ' ').title() for col in phrase_df}
phrase_df = phrase_df.rename(columns=rename_dict)
phrase_df = phrase_df[['Phrase Id', 'Added Date', 'Complexity', 'Category', 'Tone', 'Line', 'Pinyin', 'Meaning', 'Response', 'Response Pinyin','Response Meaning']]

phrase_df
# Out:
#     Phrase Id                  Added Date Complexity    Category    Tone  \
# 0     P000001                  2024-12-26     Medium  Daily Life  Casual
# 1     P000002                  2024-12-26     Medium  Daily Life  Casual
# 2     P000003                  2024-12-26     Medium  Daily Life  Casual
# 3     P000004                  2024-12-26     Medium  Daily Life  Casual
# 4     P000005                  2024-12-26     Medium  Daily Life  Casual
# ..        ...                         ...        ...         ...     ...
# 107   P000113                  2025-08-31     Medium     Cooking  Casual
# 108   P000114  2025-08-31 00:00:00.000000     Medium     Cooking  Casual
# 109   P000115  2025-08-31 00:00:00.000000     Medium     Cooking  Casual
# 110   P000116  2025-08-31 00:00:00.000000     Medium     Commute  Polite
# 111   P000117  2025-08-31 00:00:00.000000     Medium     Commute  Polite
#
#                      Line                                             Pinyin  \
# 0              我们今天晚上做什么？                 Wǒmen jīntiān wǎnshàng zuò shénme?
# 1        你觉得这个房间要不要再收拾一下？  Nǐ juéde zhège fángjiān yào bù yào zài shōushi...
# 2            你能帮我拿一下那本书吗？            Nǐ néng bāng wǒ ná yīxià nà běn shū ma?
# 3           我们还需要买点什么东西吗？         Wǒmen hái xūyào mǎi diǎn shénme dōngxī ma?
# 4    你今天下午有空吗？我们可以一起出去走走。  Nǐ jīntiān xiàwǔ yǒu kòng ma? Wǒmen kěyǐ yīqǐ ...
# ..                    ...                                                ...
# 107         你来帮我尝尝这个汤怎么样。    Nǐ lái bāng wǒ chángchang zhège tāng zěnmeyàng.
# 108            我们先切菜还是洗菜？                  Wǒmen xiān qiē cài háishì xǐ cài?
# 109          你觉得这个菜需要加盐吗？               Nǐ juéde zhège cài xūyào jiā yán ma?
# 110              今天路况怎么样？                        Jīntiān lùkuàng zěnme yàng?
# 111             到公司大概要多久？                       Dào gōngsī dàgài yào duōjiǔ?
#
#                                                Meaning           Response  \
# 0                           What should we do tonight?  你想做什么？我可以做饭或者看电影。
# 1      Do you think we should tidy up this room again?    我觉得可以，整理一下会更舒服。
# 2                      Can you help me grab that book?            当然，在哪儿？
# 3                     Do we need to buy anything else?      可能需要买一些蔬菜和水果。
# 4    Are you free this afternoon? We can go out for...      下午我有点事，但可以晚点。
# ..                                                 ...                ...
# 107                      Come help me taste this soup.           好的，我来试试。
# 108       Should we chop or wash the vegetables first?         我来洗菜，你来切菜。
# 109            Do you think this dish needs more salt?         嗯，加一点会更好吃。
# 110                          How is the traffic today?            交通还算顺畅。
# 111                      About how long to the office?           大概需要半小时。
#
#                                        Response Pinyin  \
# 0    Nǐ xiǎng zuò shénme? Wǒ kěyǐ zuò fàn huòzhě kà...
# 1         Wǒ juéde kěyǐ, zhěnglǐ yīxià huì gèng shūfu.
# 2                                    Dāngrán, zài nǎr?
# 3            Kěnéng xūyào mǎi yīxiē shūcài hé shuǐguǒ.
# 4              Xiàwǔ wǒ yǒudiǎn shì, dàn kěyǐ wǎndiǎn.
# ..                                                 ...
# 107                             Hǎo de, wǒ lái shìshi.
# 108                     Wǒ lái xǐ cài, nǐ lái qiē cài.
# 109                     Ń, jiā yīdiǎn huì gèng hǎochī.
# 110                       Jiāotōng hái suàn shùnchàng.
# 111                           Dàgài xūyào bàn xiǎoshí.
#
#                                       Response Meaning
# 0    What do you want to do? I can cook or we can w...
# 1    I think we can, tidying it up will make it mor...
# 2                              Of course, where is it?
# 3     We might need to buy some vegetables and fruits.
# 4    I have some things in the afternoon, but I can...
# ..                                                 ...
# 107                               Sure, let me try it.
# 108           I'll wash the vegetables, you chop them.
# 109         Hmm, adding a little will make it tastier.
# 110                      The traffic is fairly smooth.
# 111                       It takes about half an hour.
#
# [112 rows x 11 columns]

# %%
# Out:
#     Phrase Id                  Line  \
# 0     P000001            我们今天晚上做什么？
# 1     P000002      你觉得这个房间要不要再收拾一下？
# 2     P000003          你能帮我拿一下那本书吗？
# 3     P000004         我们还需要买点什么东西吗？
# 4     P000005  你今天下午有空吗？我们可以一起出去走走。
# ..        ...                   ...
# 107   P000113         你来帮我尝尝这个汤怎么样。
# 108   P000114            我们先切菜还是洗菜？
# 109   P000115          你觉得这个菜需要加盐吗？
# 110   P000116              今天路况怎么样？
# 111   P000117             到公司大概要多久？
#
#                                                 Pinyin  \
# 0                   Wǒmen jīntiān wǎnshàng zuò shénme?
# 1    Nǐ juéde zhège fángjiān yào bù yào zài shōushi...
# 2              Nǐ néng bāng wǒ ná yīxià nà běn shū ma?
# 3           Wǒmen hái xūyào mǎi diǎn shénme dōngxī ma?
# 4    Nǐ jīntiān xiàwǔ yǒu kòng ma? Wǒmen kěyǐ yīqǐ ...
# ..                                                 ...
# 107    Nǐ lái bāng wǒ chángchang zhège tāng zěnmeyàng.
# 108                  Wǒmen xiān qiē cài háishì xǐ cài?
# 109               Nǐ juéde zhège cài xūyào jiā yán ma?
# 110                        Jīntiān lùkuàng zěnme yàng?
# 111                       Dào gōngsī dàgài yào duōjiǔ?
#
#                                                Meaning           Response  \
# 0                           What should we do tonight?  你想做什么？我可以做饭或者看电影。
# 1      Do you think we should tidy up this room again?    我觉得可以，整理一下会更舒服。
# 2                      Can you help me grab that book?            当然，在哪儿？
# 3                     Do we need to buy anything else?      可能需要买一些蔬菜和水果。
# 4    Are you free this afternoon? We can go out for...      下午我有点事，但可以晚点。
# ..                                                 ...                ...
# 107                      Come help me taste this soup.           好的，我来试试。
# 108       Should we chop or wash the vegetables first?         我来洗菜，你来切菜。
# 109            Do you think this dish needs more salt?         嗯，加一点会更好吃。
# 110                          How is the traffic today?            交通还算顺畅。
# 111                      About how long to the office?           大概需要半小时。
#
#                                        Response Pinyin  \
# 0    Nǐ xiǎng zuò shénme? Wǒ kěyǐ zuò fàn huòzhě kà...
# 1         Wǒ juéde kěyǐ, zhěnglǐ yīxià huì gèng shūfu.
# 2                                    Dāngrán, zài nǎr?
# 3            Kěnéng xūyào mǎi yīxiē shūcài hé shuǐguǒ.
# 4              Xiàwǔ wǒ yǒudiǎn shì, dàn kěyǐ wǎndiǎn.
# ..                                                 ...
# 107                             Hǎo de, wǒ lái shìshi.
# 108                     Wǒ lái xǐ cài, nǐ lái qiē cài.
# 109                     Ń, jiā yīdiǎn huì gèng hǎochī.
# 110                       Jiāotōng hái suàn shùnchàng.
# 111                           Dàgài xūyào bàn xiǎoshí.
#
#                                       Response Meaning Complexity    Category  \
# 0    What do you want to do? I can cook or we can w...     Medium  Daily Life
# 1    I think we can, tidying it up will make it mor...     Medium  Daily Life
# 2                              Of course, where is it?     Medium  Daily Life
# 3     We might need to buy some vegetables and fruits.     Medium  Daily Life
# 4    I have some things in the afternoon, but I can...     Medium  Daily Life
# ..                                                 ...        ...         ...
# 107                               Sure, let me try it.     Medium     Cooking
# 108           I'll wash the vegetables, you chop them.     Medium     Cooking
# 109         Hmm, adding a little will make it tastier.     Medium     Cooking
# 110                      The traffic is fairly smooth.     Medium     Commute
# 111                       It takes about half an hour.     Medium     Commute
#
#        Tone                  Added Date
# 0    Casual                  2024-12-26
# 1    Casual                  2024-12-26
# 2    Casual                  2024-12-26
# 3    Casual                  2024-12-26
# 4    Casual                  2024-12-26
# ..      ...                         ...
# 107  Casual                  2025-08-31
# 108  Casual  2025-08-31 00:00:00.000000
# 109  Casual  2025-08-31 00:00:00.000000
# 110  Polite  2025-08-31 00:00:00.000000
# 111  Polite  2025-08-31 00:00:00.000000
#
# [112 rows x 11 columns]

# %% [markdown]
# ### Old Manual Code

# %% [markdown]
# sdfsdfsdfs

# %%
df = pd.read_csv("data/MandarinWordList.csv")
df.columns = [col.lower().replace(" ", "_") for col in df.columns]

# %%
df.dtypes
# Out:
# word_id              object
# word                 object
# pinyin               object
# pinyin_simplified    object
# type                 object
# word_category        object
# word_rarity          object
# meaning              object
# sentence             object
# sentence_pinyin      object
# sentence_meaning     object
# added_date           object
# num_quiz_attempt      int64
# num_correct           int64
# num_wrong             int64
# last_quiz            object
# dtype: object

# %%
df['sentence_pinyin'] = df['sentence_pinyin'].fillna('')
df['sentence'] = df['sentence'].fillna('')
df['sentence_meaning'] = df['sentence_meaning'].fillna('')

df['added_date'] = pd.to_datetime(df['added_date'], errors='coerce')
df['last_quiz'] = pd.to_datetime(df['last_quiz'], errors='coerce')

# %%
from sqlalchemy import Column, Integer, String, DateTime, func
from sqlalchemy import ForeignKey
from sqlalchemy.orm import declarative_base

Base = declarative_base()

class WordDict(Base):
    __tablename__ = "WordDict"  
    word_id = Column(String, nullable=False, unique=True, primary_key=True, index=True)
    word = Column(String, nullable=False)
    pinyin = Column(String, nullable=False)
    pinyin_simplified = Column(String, nullable=False)
    type = Column(String, nullable=False)
    word_category = Column(String, nullable=False)
    word_rarity = Column(String, nullable=False)
    meaning = Column(String, nullable=False)
    sentence = Column(String, nullable=False)
    sentence_pinyin = Column(String, nullable=False)
    sentence_meaning = Column(String, nullable=False)
    added_date = Column(DateTime(timezone=True), server_default=func.now())
    #It's better to track quiz stats in a separate table to allow for multiple quiz attempts over time
    #We can display quiz stats in the app by querying the quiz attempts table and doing groupby 
    #num_quiz_attempt = Column(Integer, default=0)
    #num_correct = Column(Integer, default=0)
    #num_wrong = Column(Integer, default=0)
    #last_quiz = Column(DateTime(timezone=True), nullable=True)

class QuizAgg(Base):
    __tablename__ = "QuizAgg"  
    word_id = Column(String, ForeignKey("WordDict.word_id", ondelete="CASCADE"), primary_key=True)
    num_quiz_attempt = Column(Integer, default=0)
    num_correct = Column(Integer, default=0)
    num_wrong = Column(Integer, default=0)
    last_quiz = Column(DateTime(timezone=True), nullable=True)

# %%
df.word_id.value_counts().sort_values(ascending=False).head(10)
# Out:
# word_id
# D000001    1
# D000016    1
# D000005    1
# D000006    1
# D000007    1
# D000008    1
# D000009    1
# D000010    1
# D000011    1
# D000012    1
# Name: count, dtype: int64

# %%
engine = create_engine("sqlite:///mydata.db", future=True)
Base.metadata.create_all(bind=engine)

df.drop(['num_quiz_attempt', 'num_correct', 'num_wrong', 'last_quiz'], axis=1).to_sql(WordDict.__tablename__, engine, if_exists="append", index=False)
df[['word_id', 'num_quiz_attempt', 'num_correct', 'num_wrong', 'last_quiz']].to_sql(QuizAgg.__tablename__, engine, if_exists="append", index=False)
# Out:
# 1903

# %%
inspector = inspect(engine)

# List tables
print(inspector.get_table_names())

# Get columns for a table
for col in inspector.get_columns("WordDict"):
    print(col['name'], col['type'])
# Out:
# ['QuizAgg', 'WordDict']
# word_id VARCHAR
# word VARCHAR
# pinyin VARCHAR
# pinyin_simplified VARCHAR
# type VARCHAR
# word_category VARCHAR
# word_rarity VARCHAR
# meaning VARCHAR
# sentence VARCHAR
# sentence_pinyin VARCHAR
# sentence_meaning VARCHAR
# added_date DATETIME

# %%
inspector.get_columns('WordDict')
# Out:
# [{'name': 'word_id',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 1},
#  {'name': 'word',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'pinyin',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'pinyin_simplified',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'type',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'word_category',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'word_rarity',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'meaning',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'sentence',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'sentence_pinyin',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'sentence_meaning',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'added_date',
#   'type': DATETIME(),
#   'nullable': True,
#   'default': 'CURRENT_TIMESTAMP',
#   'primary_key': 0}]

# %%
pd.read_sql("SELECT COUNT(*) FROM WordDict", engine)
# Out:
#    COUNT(*)
# 0      1903

# %%
base = int(val.replace("D","")) if val else 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 base = int(val.replace("D","")) if val else 0
#
# NameError: name 'val' is not defined

# %%
val = pd.read_sql("SELECT MAX(word_id) AS max_id FROM WordDict", engine)["max_id"].iat[0]
base = int(val.replace("D","")) if val else 0
new_ids = [f"D{base+i:06d}" for i in range(1, len(df)+1)]
new_ids
# Out:
# ['D002646']
