# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
import main.Constants as Constants
from  openai import OpenAI
import os
import numpy as np
import pandas as pd
import time

import gspread
import gspread_dataframe as gd
import gspread_formatting as gf
from gspread_formatting import cellFormat, color, textFormat

# %% [markdown]
# ## Sample OpenAI Prompt Completion

# %%
client = OpenAI(
    api_key = Constants.API_KEY_OPENAI,
)

def get_completion(prompt, model="gpt-4o-mini", temperature=0):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )
    return response

# %% [markdown]
# ## Test Google Sheet API

# %%
# No need to provide path for service account.  Json file is in the default directory for gspread at %APPDATA%/gspread/service_account.json
sa = gspread.service_account()
sh = sa.open("New Chinese Words")

sheet_name = "Tua_List"
wks2 = sh.worksheet(sheet_name)
print(f'Sheet {sheet_name} Num Rows: {wks2.row_count}')
print(f'Sheet {sheet_name} Num Columns: {wks2.col_count}')
# Out:
# Sheet Tua_List Num Rows: 1904
# Sheet Tua_List Num Columns: 17

# %%
current_data = pd.DataFrame(wks2.get_all_values())
current_data.columns = current_data.iloc[0]
current_data = current_data.iloc[1:]
current_data.head()
# Out:
# 0  Word Id Word      Pinyin Pinyin Simplified       Type Word Category  \
# 1  D000001   帮助  bang1 zhu4        bang1 zhu4  Noun/Verb       Support
# 2  D000002   包裹   bao1 guo3         bao1 guo3       Noun        Object
# 3  D000004   不错    bu2 cuo4          bu2 cuo4  Adjective       Opinion
# 4  D000005   不过    bu2 guo4          bu2 guo4    Grammar       Grammar
# 5  D000006   不太    bu2 tai4          bu2 tai4   Adjuster        Degree
#
# 0 Word Rarity                                     Meaning          Sentence  \
# 1      Common                             Help/Assistance        我可以帮助你学习中文
# 2      Common                                     Package       他昨天收到了一个包裹。
# 3      Common                Good (More positive than 还好)  这个电影不错，我们可以一起去看。
# 4      Common  But (Similar to dan4 shi4 but less formal)  我喜欢这家餐厅，不过价格有点贵。
# 5      Common                                   not quite               不太好
#
# 0                                    Sentence Pinyin  \
# 1                 Wǒ kěyǐ bāngzhù nǐ xuéxí Zhōngwén.
# 2                      Wǒ zuótiān shōudào le bāoguǒ.
# 3       Zhè gè diànyǐng bùcuò wǒmen kěyǐ yìqǐ qù kàn
# 4  Wǒ xǐhuān zhè jiā cāntīng búguò jiàgé yǒudiǎn ...
# 5                                      bu2 tai4 hao3
#
# 0                                   Sentence Meaning  Added Date  \
# 1                      I can help you study Chinese.  2024-09-21
# 2                  I received the package yesterday.  2024-09-21
# 3  This movie is pretty good; we can go watch it ...  2024-09-21
# 4  I like this restaurant but the price is a bit ...  2024-09-21
# 5                                     not quite good  2024-09-21
#
# 0 Num_Quiz_Attempt Num_Correct Num_Wrong   Last_Quiz
# 1                0           0         0
# 2                0           0         0
# 3                1           1         0  2024-12-26
# 4                0           0         0
# 5                1           1         0  2025-01-05

# %% [markdown]
# ## Chinese Language Translation

# %%
from main.translation import *

# %%
dict_sheet_name = "Tua_List"
gsheet_name = "New Chinese Words"


df = load_dict(gsheet_mode=True, gsheet_name=gsheet_name, worksheet_name=dict_sheet_name)
cat = df['Word Category'].drop_duplicates().sort_values().to_list()

translator_pipe = TranslationPipeline(gsheet_name=gsheet_name, worksheet_name=dict_sheet_name)

# %%
from database import init_db, engine
from sql import sql_update_worddict

init_db()

# %%
pd.read_sql("SELECT * FROM WordDict", engine)
# Out:
#       word_id word      pinyin pinyin_simplified       type word_category  \
# 0     D000001   帮助  bang1 zhu4        bang1 zhu4  Noun/Verb       Support
# 1     D000002   包裹   bao1 guo3         bao1 guo3       Noun        Object
# 2     D000004   不错    bu2 cuo4          bu2 cuo4  Adjective       Opinion
# 3     D000005   不过    bu2 guo4          bu2 guo4    Grammar       Grammar
# 4     D000006   不太    bu2 tai4          bu2 tai4   Adjuster        Degree
# ...       ...  ...         ...               ...        ...           ...
# 1900  D002645   优秀     yōu xiù         you1 xiu4  Adjective   Description
# 1901  D002650   适应    shì yìng        shi4 ying4       Verb    Adaptation
# 1902  D002651   阳光  yáng guāng      yang2 guang1       Noun        Nature
# 1903  D002652   混蛋     hún dàn         hun2 dan4       Noun       Emotion
# 1904  D002653   动手   dòng shǒu       dong4 shou3       Verb        Action
#
#      word_rarity                                            meaning  \
# 0         Common                                    Help/Assistance
# 1         Common                                            Package
# 2         Common                       Good (More positive than 还好)
# 3         Common         But (Similar to dan4 shi4 but less formal)
# 4         Common                                          not quite
# ...          ...                                                ...
# 1900        Rare           Excellent; extremely good or outstanding
# 1901      Common  To become accustomed to a new environment or s...
# 1902      Common                    Sunlight; the light of the sun.
# 1903      Common  An offensive term for a scoundrel or rascal; o...
# 1904      Common  To start doing something, often implying manua...
#
#               sentence                                    sentence_pinyin  \
# 0           我可以帮助你学习中文                 Wǒ kěyǐ bāngzhù nǐ xuéxí Zhōngwén.
# 1          他昨天收到了一个包裹。                      Wǒ zuótiān shōudào le bāoguǒ.
# 2     这个电影不错，我们可以一起去看。       Zhè gè diànyǐng bùcuò wǒmen kěyǐ yìqǐ qù kàn
# 3     我喜欢这家餐厅，不过价格有点贵。  Wǒ xǐhuān zhè jiā cāntīng búguò jiàgé yǒudiǎn ...
# 4                  不太好                                      bu2 tai4 hao3
# ...                ...                                                ...
# 1900        她是一个优秀的学生。                   Tā shì yī gè yōuxiù de xuéshēng.
# 1901     他很快适应了新的工作环境。    Tā hěn kuài shìyìng le xīn de gōngzuò huánjìng.
# 1902       阳光透过窗户照进房间。        Yángguāng tòuguò chuānghù zhàojìn fángjiān.
# 1903     他真是个混蛋，居然骗了我。           Tā zhēn shì gè húndàn, jūrán piàn le wǒ.
# 1904   我们快点动手吧，不然来不及了。   Wǒmen kuài diǎn dòngshǒu ba, bùrán lái bu jí le.
#
#                                        sentence_meaning  \
# 0                         I can help you study Chinese.
# 1                     I received the package yesterday.
# 2     This movie is pretty good; we can go watch it ...
# 3     I like this restaurant but the price is a bit ...
# 4                                        not quite good
# ...                                                 ...
# 1900                       She is an excellent student.
# 1901    He quickly adapted to the new work environment.
# 1902  Sunlight streamed through the window into the ...
# 1903        He is such a jerk, he actually deceived me.
# 1904  Let's start quickly, or we won't make it in time.
#
#                       added_date
# 0     2024-09-21 00:00:00.000000
# 1     2024-09-21 00:00:00.000000
# 2     2024-09-21 00:00:00.000000
# 3     2024-09-21 00:00:00.000000
# 4     2024-09-21 00:00:00.000000
# ...                          ...
# 1900  2025-06-21 00:00:00.000000
# 1901  2025-08-17 00:00:00.000000
# 1902  2025-08-17 00:00:00.000000
# 1903  2025-08-17 00:00:00.000000
# 1904  2025-08-17 00:00:00.000000
#
# [1905 rows x 12 columns]

# %%
translator_pipe.run_translation_pipeline(word_list=['适应', '阳光', '混蛋', '动手'])
# Out:
# 'Overwrite mode enabled.  Replacing 4 words and 0 new words added.'

# %%
pd.read_sql("SELECT * FROM WordDict", engine)
# Out:
#       word_id word      pinyin pinyin_simplified       type word_category  \
# 0     D000001   帮助  bang1 zhu4        bang1 zhu4  Noun/Verb       Support
# 1     D000002   包裹   bao1 guo3         bao1 guo3       Noun        Object
# 2     D000004   不错    bu2 cuo4          bu2 cuo4  Adjective       Opinion
# 3     D000005   不过    bu2 guo4          bu2 guo4    Grammar       Grammar
# 4     D000006   不太    bu2 tai4          bu2 tai4   Adjuster        Degree
# ...       ...  ...         ...               ...        ...           ...
# 1902  D002655   阳光  yáng guāng      yang2 guang1       Noun        Nature
# 1903  D002656   阳光  yáng guāng      yang2 guang1  Adjective     Character
# 1904  D002657   混蛋     hún dàn         hun2 dan4       Noun       Emotion
# 1905  D002658   动手   dòng shǒu       dong4 shou3       Verb        Action
# 1906  D002659   动手   dòng shǒu       dong4 shou3       Verb      Behavior
#
#      word_rarity                                            meaning  \
# 0         Common                                    Help/Assistance
# 1         Common                                            Package
# 2         Common                       Good (More positive than 还好)
# 3         Common         But (Similar to dan4 shi4 but less formal)
# 4         Common                                          not quite
# ...          ...                                                ...
# 1902      Common  Sunlight; the light or warmth that comes from ...
# 1903      Common  Optimistic or cheerful; having a bright and po...
# 1904      Common  A contemptible or despicable person; often use...
# 1905      Common  To start doing something; to begin a task or a...
# 1906      Common  To physically attack or hit someone; to use on...
#
#               sentence                                    sentence_pinyin  \
# 0           我可以帮助你学习中文                 Wǒ kěyǐ bāngzhù nǐ xuéxí Zhōngwén.
# 1          他昨天收到了一个包裹。                      Wǒ zuótiān shōudào le bāoguǒ.
# 2     这个电影不错，我们可以一起去看。       Zhè gè diànyǐng bùcuò wǒmen kěyǐ yìqǐ qù kàn
# 3     我喜欢这家餐厅，不过价格有点贵。  Wǒ xǐhuān zhè jiā cāntīng búguò jiàgé yǒudiǎn ...
# 4                  不太好                                      bu2 tai4 hao3
# ...                ...                                                ...
# 1902      阳光透过窗户洒在地板上。      Yángguāng tòuguò chuānghù sǎ zài dìbǎn shàng.
# 1903   她总是那么阳光，感染身边的人。  Tā zǒng shì nàme yángguāng, gǎnrǎn shēnbiān de...
# 1904     他真是个混蛋，居然骗了我。           Tā zhēn shì gè húndàn, jūrán piàn le wǒ.
# 1905  开始动手，我们还有很多工作要做。  Kāishǐ dòngshǒu, wǒmen hái yǒu hěn duō gōngzuò...
# 1906     他因为一点小事就动手打人。      Tā yīnwèi yīdiǎn xiǎoshì jiù dòngshǒu dǎ rén.
#
#                                        sentence_meaning  \
# 0                         I can help you study Chinese.
# 1                     I received the package yesterday.
# 2     This movie is pretty good; we can go watch it ...
# 3     I like this restaurant but the price is a bit ...
# 4                                        not quite good
# ...                                                 ...
# 1902  Sunlight shines through the window onto the fl...
# 1903  She is always so cheerful, spreading positivit...
# 1904                 He's such a jerk for deceiving me.
# 1905    Let's get started, we have a lot of work to do.
# 1906           He hit someone just over a small matter.
#
#                       added_date
# 0     2024-09-21 00:00:00.000000
# 1     2024-09-21 00:00:00.000000
# 2     2024-09-21 00:00:00.000000
# 3     2024-09-21 00:00:00.000000
# 4     2024-09-21 00:00:00.000000
# ...                          ...
# 1902  2025-08-17 00:00:00.000000
# 1903  2025-08-17 00:00:00.000000
# 1904  2025-08-17 00:00:00.000000
# 1905  2025-08-17 00:00:00.000000
# 1906  2025-08-17 00:00:00.000000
#
# [1907 rows x 12 columns]

# %%
 pd.read_sql("SELECT * FROM QuizAgg", engine)
# Out:
#       word_id  num_quiz_attempt  num_correct  num_wrong  \
# 0     D000001                 0            0          0
# 1     D000002                 0            0          0
# 2     D000004                 1            1          0
# 3     D000005                 0            0          0
# 4     D000006                 1            1          0
# ...       ...               ...          ...        ...
# 1902  D002655                 0            0          0
# 1903  D002656                 0            0          0
# 1904  D002657                 0            0          0
# 1905  D002658                 0            0          0
# 1906  D002659                 0            0          0
#
#                        last_quiz
# 0                           None
# 1                           None
# 2     2024-12-26 00:00:00.000000
# 3                           None
# 4     2025-01-05 00:00:00.000000
# ...                          ...
# 1902                        None
# 1903                        None
# 1904                        None
# 1905                        None
# 1906                        None
#
# [1907 rows x 5 columns]

# %%
word_list = """
            适应, 
            阳光, 
            分析, 
            冥想
            """

# %%
#translator_pipe.translation_module(word_list=word_list, temp=0.7)

# %%
#translator_pipe.new_words_df

# %%
#translator_pipe.update_module(overwrite_mode=True)

# %%
translator_pipe.run_translation_pipeline(word_list=word_list, translation_model="gpt-4o", temp=0.5, overwrite_mode=True)
# Out:
# 'Overwrite mode enabled.  Replacing 1 words and 3 new words added.'

# %% [markdown]
# ## For Debugging Duplicate Words

# %%
if hasattr(translator_pipe, 'new_words_df'):
    message = save_new_words_to_dict(
        newwords_df = translator_pipe.new_words_df,
        gsheet_mode= True,
        overwrite_mode = True,
        gsheet_name = translator_pipe.gsheet_name,
        worksheet_name = translator_pipe.worksheet_name
    )

    message
else:
    raise Exception("Run the translation module first before running the update module.")

# %%
newwords_df = translator_pipe.new_words_df
gsheet_mode = True
gsheet_name = translator_pipe.gsheet_name
worksheet_name = translator_pipe.worksheet_name
overwrite_mode = True

new_words = newwords_df['Word'].drop_duplicates().values

if gsheet_mode:
    chinese_dict = load_dict(gsheet_mode=gsheet_mode, gsheet_name=gsheet_name, worksheet_name=worksheet_name)

max_id = pd.to_numeric(chinese_dict['Word Id'], errors='coerce').max()
newwords_df['Word Id'] = [num + max_id for num in range(1, len(newwords_df) + 1)]
newwords_df['Num_Quiz_Attempt'] = 0
newwords_df['Num_Correct'] = 0
newwords_df['Num_Wrong'] = 0
newwords_df['Last_Quiz'] = ''

missing_cols = [col for col in chinese_dict.columns if col not in newwords_df.columns]
if len(missing_cols) > 0:
    raise Exception(f"Missing columns in df to add: {missing_cols}")

newwords_df = newwords_df[chinese_dict.columns]
existing_words = chinese_dict['Word'].drop_duplicates().values

starting_words_len = len(existing_words)
new_words_len = len(new_words)

print(new_words)
if overwrite_mode:
    print(f'Word Before: {chinese_dict.loc[chinese_dict.Word.isin(new_words)][['Word Id', 'Word']]}')
    chinese_dict = chinese_dict.loc[~chinese_dict.Word.isin(new_words)]
    print(f'Word After: {chinese_dict.loc[chinese_dict.Word.isin(new_words)][['Word Id', 'Word']]}')
    if len(chinese_dict.loc[chinese_dict.Word.isin(new_words)]) == 0:

        dedup_words_len = len(chinese_dict['Word'].drop_duplicates().values)
        chinese_dict = pd.concat([chinese_dict, newwords_df])
    
    else:
        raise Exception("Some words in the new words list already exist in the dictionary.  Please disable overwrite mode to add new words.")
        
    message = f"Overwrite mode enabled.  Replacing {starting_words_len - dedup_words_len} words and {new_words_len - (starting_words_len - dedup_words_len)} new words added."

else: 
    newwords_df = newwords_df.loc[~newwords_df.Word.isin(existing_words)]
    dedup_words_len = len(newwords_df['Word'].drop_duplicates().values)
    chinese_dict = pd.concat([chinese_dict, newwords_df])
    
    message = f"Overwrite mode disabled.  {new_words_len - dedup_words_len} exists in current dictionary, adding {dedup_words_len} words."

chinese_dict = chinese_dict.loc[(chinese_dict['Word Id'].notnull()) & (chinese_dict['Word Id'] != '')]
chinese_dict['Word'] = chinese_dict['Word'].str.strip()

if gsheet_mode:
    #Save empty df first to clear the worksheet
    save_df_to_gsheet(gsheet_name, worksheet_name, pd.DataFrame(), overwrite_mode=overwrite_mode)
    save_df_to_gsheet(gsheet_name, worksheet_name, chinese_dict, overwrite_mode=overwrite_mode)

message
# Out:
# ['适应' '阳光' '分析' '冥想']
# Word Before: 0     Word Id Word
# 1264  D001828   适应
# 1265  D001829   阳光
# 1266  D001830   分析
# 1267  D001831   冥想
# Word After: Empty DataFrame
# Columns: [Word Id, Word]
# Index: []
# 'Overwrite mode enabled.  Replacing 4 words and 0 new words added.'

# %%
chinese_dict2 = load_dict(gsheet_mode=gsheet_mode, gsheet_name=gsheet_name, worksheet_name=worksheet_name)
chinese_dict2
# Out:
# 0     Word Id Word      Pinyin Pinyin Simplified       Type Word Category  \
# 1     D000001   帮助  bang1 zhu4        bang1 zhu4  Noun/Verb       Support
# 2     D000002   包裹   bao1 guo3         bao1 guo3       Noun        Object
# 3     D000004   不错    bu2 cuo4          bu2 cuo4  Adjective       Opinion
# 4     D000005   不过    bu2 guo4          bu2 guo4    Grammar       Grammar
# 5     D000006   不太    bu2 tai4          bu2 tai4   Adjuster        Degree
# ...       ...  ...         ...               ...        ...           ...
# 1259  D001818    累         lèi              lei4  Adjective       Emotion
# 1260  D001819   分派     fēn pài         fen1 pai4       Verb          Work
# 1261  D001820   分派     fēn pài         fen1 pai4       Verb     Economics
# 1262  D001822   道理      dào lǐ          dao4 li3       Noun       Thought
# 1263  D001823   分手    fēn shǒu        fen1 shou3       Verb  Relationship
#
# 0    Word Rarity                                            Meaning  \
# 1         Common                                    Help/Assistance
# 2         Common                                            Package
# 3         Common                       Good (More positive than 还好)
# 4         Common         But (Similar to dan4 shi4 but less formal)
# 5         Common                                          not quite
# ...          ...                                                ...
# 1259      Common                                              Tired
# 1260      Common  To assign tasks or distribute responsibilities...
# 1261      Common                To distribute or allocate resources
# 1262      Common                Logic or sense; coherent reasoning.
# 1263      Common        To break up; to end a romantic relationship
#
# 0               Sentence                                    Sentence Pinyin  \
# 1             我可以帮助你学习中文                 Wǒ kěyǐ bāngzhù nǐ xuéxí Zhōngwén.
# 2            他昨天收到了一个包裹。                      Wǒ zuótiān shōudào le bāoguǒ.
# 3       这个电影不错，我们可以一起去看。       Zhè gè diànyǐng bùcuò wǒmen kěyǐ yìqǐ qù kàn
# 4       我喜欢这家餐厅，不过价格有点贵。  Wǒ xǐhuān zhè jiā cāntīng búguò jiàgé yǒudiǎn ...
# 5                    不太好                                      bu2 tai4 hao3
# ...                  ...                                                ...
# 1259            我今天工作很累。                        Wǒ jīntiān gōngzuò hěn lèi.
# 1260        老板分派给我一个新项目。             Lǎobǎn fēnpài gěi wǒ yīgè xīn xiàngmù.
# 1261       他们把物资分派给需要的人。             Tāmen bǎ wùzī fēnpài gěi xūyào de rén.
# 1262      他的解释虽然复杂，但有道理。           Tā de jiěshì suīrán fùzá, dàn yǒu dàolǐ.
# 1263  他们决定和平分手，各自追求新的生活。  Tāmen juédìng hépíng fēnshǒu, gèzì zhuīqiú xīn...
#
# 0                                      Sentence Meaning  Added Date  \
# 1                         I can help you study Chinese.  2024-09-21
# 2                     I received the package yesterday.  2024-09-21
# 3     This movie is pretty good; we can go watch it ...  2024-09-21
# 4     I like this restaurant but the price is a bit ...  2024-09-21
# 5                                        not quite good  2024-09-21
# ...                                                 ...         ...
# 1259                   I am very tired from work today.  2025-01-19
# 1260                The boss assigned me a new project.  2025-01-19
# 1261   They distributed the resources to those in need.  2025-01-19
# 1262      His explanation, though complex, makes sense.  2025-01-19
# 1263  They decided to break up amicably and pursue n...  2025-01-19
#
# 0    Num_Quiz_Attempt Num_Correct Num_Wrong   Last_Quiz
# 1                   0           0         0
# 2                   0           0         0
# 3                   1           1         0  2024-12-26
# 4                   0           0         0
# 5                   1           1         0  2025-01-05
# ...               ...         ...       ...         ...
# 1259                0           0         0
# 1260                0           0         0
# 1261                0           0         0
# 1262                0           0         0
# 1263                0           0         0
#
# [1263 rows x 16 columns]

# %%
sa = gspread.service_account()
sh = sa.open(gsheet_name)
wks = sh.worksheet(worksheet_name)

if not overwrite_mode:
    print('Not Overwrite Mode')
    existing = gd.get_as_dataframe(wks)
    df_to_save = pd.concat([existing, df_to_save])

wks.batch_clear(["A:Q"])
gd.set_with_dataframe(wks, pd.DataFrame())

# %%
wks.batch_clear(["A:Q"])
# Out:
# {'spreadsheetId': '1GVz04WQyGWf4e6dH0Bwdb_YLNF_ZuUks0YWrEUOUF-c',
#  'clearedRanges': ['Tua_List!A1:Q1858']}

# %%
save_df_to_gsheet(gsheet_name, worksheet_name, chinese_dict, overwrite_mode=overwrite_mode)

# %%
chinese_dict
# Out:
#       Word Id Word      Pinyin Pinyin Simplified       Type Word Category  \
# 1     D000001   帮助  bang1 zhu4        bang1 zhu4  Noun/Verb       Support
# 2     D000002   包裹   bao1 guo3         bao1 guo3       Noun        Object
# 3     D000004   不错    bu2 cuo4          bu2 cuo4  Adjective       Opinion
# 4     D000005   不过    bu2 guo4          bu2 guo4    Grammar       Grammar
# 5     D000006   不太    bu2 tai4          bu2 tai4   Adjuster        Degree
# ...       ...  ...         ...               ...        ...           ...
# 1259  D001818    累         lèi              lei4  Adjective       Emotion
# 1260  D001819   分派     fēn pài         fen1 pai4       Verb          Work
# 1261  D001820   分派     fēn pài         fen1 pai4       Verb     Economics
# 1262  D001822   道理      dào lǐ          dao4 li3       Noun       Thought
# 1263  D001823   分手    fēn shǒu        fen1 shou3       Verb  Relationship
#
#      Word Rarity                                            Meaning  \
# 1         Common                                    Help/Assistance
# 2         Common                                            Package
# 3         Common                       Good (More positive than 还好)
# 4         Common         But (Similar to dan4 shi4 but less formal)
# 5         Common                                          not quite
# ...          ...                                                ...
# 1259      Common                                              Tired
# 1260      Common  To assign tasks or distribute responsibilities...
# 1261      Common                To distribute or allocate resources
# 1262      Common                Logic or sense; coherent reasoning.
# 1263      Common        To break up; to end a romantic relationship
#
#                 Sentence                                    Sentence Pinyin  \
# 1             我可以帮助你学习中文                 Wǒ kěyǐ bāngzhù nǐ xuéxí Zhōngwén.
# 2            他昨天收到了一个包裹。                      Wǒ zuótiān shōudào le bāoguǒ.
# 3       这个电影不错，我们可以一起去看。       Zhè gè diànyǐng bùcuò wǒmen kěyǐ yìqǐ qù kàn
# 4       我喜欢这家餐厅，不过价格有点贵。  Wǒ xǐhuān zhè jiā cāntīng búguò jiàgé yǒudiǎn ...
# 5                    不太好                                      bu2 tai4 hao3
# ...                  ...                                                ...
# 1259            我今天工作很累。                        Wǒ jīntiān gōngzuò hěn lèi.
# 1260        老板分派给我一个新项目。             Lǎobǎn fēnpài gěi wǒ yīgè xīn xiàngmù.
# 1261       他们把物资分派给需要的人。             Tāmen bǎ wùzī fēnpài gěi xūyào de rén.
# 1262      他的解释虽然复杂，但有道理。           Tā de jiěshì suīrán fùzá, dàn yǒu dàolǐ.
# 1263  他们决定和平分手，各自追求新的生活。  Tāmen juédìng hépíng fēnshǒu, gèzì zhuīqiú xīn...
#
#                                        Sentence Meaning  Added Date  \
# 1                         I can help you study Chinese.  2024-09-21
# 2                     I received the package yesterday.  2024-09-21
# 3     This movie is pretty good; we can go watch it ...  2024-09-21
# 4     I like this restaurant but the price is a bit ...  2024-09-21
# 5                                        not quite good  2024-09-21
# ...                                                 ...         ...
# 1259                   I am very tired from work today.  2025-01-19
# 1260                The boss assigned me a new project.  2025-01-19
# 1261   They distributed the resources to those in need.  2025-01-19
# 1262      His explanation, though complex, makes sense.  2025-01-19
# 1263  They decided to break up amicably and pursue n...  2025-01-19
#
#      Num_Quiz_Attempt Num_Correct Num_Wrong   Last_Quiz
# 1                   0           0         0
# 2                   0           0         0
# 3                   1           1         0  2024-12-26
# 4                   0           0         0
# 5                   1           1         0  2025-01-05
# ...               ...         ...       ...         ...
# 1259                0           0         0
# 1260                0           0         0
# 1261                0           0         0
# 1262                0           0         0
# 1263                0           0         0
#
# [1263 rows x 16 columns]

# %% [markdown]
# ## Step by Step Pipeline

# %%
temp = 0.7
sample_response_translation = (
    get_completion(
        prompt=get_prompt_for_chinese_translation(word_list), model="gpt-4o-mini" , temperature=temp))
content = sample_response_translation.choices[0].message.content

newwords_df = (
    parse_response_table(
        content,
        ffill_cols = ['Word', 'Pinyin', 'Pinyin Simplified', 'Type'],
        date_col = ['Added Date']
        )
      )

new_words = newwords_df['Word'].drop_duplicates().values
newwords_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 sample_response_translation = (
#       2     get_completion(
# ----> 3         prompt=get_prompt_for_chinese_translation(word_list), model="gpt-4o-mini" , temperature=temp))
#       4 content = sample_response_translation.choices[0].message.content
#       6 newwords_df = (
#       7     parse_translation_response(
#       8         content,
#    (...)
#      11         )
#      12       )
#
# NameError: name 'temp' is not defined

# %%
sample_response_translation = (
    get_completion(
        prompt=get_prompt_for_rarity_classification(word_list), model="gpt-4o-mini" , temperature=temp))
content = sample_response_translation.choices[0].message.content

word_rarity_df = parse_translation_response(content)
word_rarity_df
# Out:
# c:\Users\wongs\Documents\DS Work\repo\Pytorch LLM\GPT4LanguageLearning\main\translation.py:233: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#   Word Word Rarity
# 1   地图      Common
# 2   晚点      Common
# 3   起飞      Common
# 4   降落      Common

# %%
save_new_words_to_dict(
    newwords_df = newwords_df.merge(word_rarity_df, on='Word', how='left'),
    gsheet_mode= True,
    overwrite_mode = True,
    gsheet_name = gsheet_name,
    worksheet_name = dict_sheet_name)
# Out:
# Overwrite mode enabled.  Replacing 0 words and 4 new words added.

# %% [markdown]
# ## Batch Update

# %%
df = load_dict(gsheet_mode=True, gsheet_name=gsheet_name, worksheet_name=dict_sheet_name)
word_list = df['Word'].drop_duplicates().to_list()

# %%
import time
from tqdm import tqdm

all_dfs = []
max_retries = 3  # Set the number of retries per item
attempt = 0
batch_size = 5 

for i in tqdm(range(0, len(word_list), batch_size)):
    if attempt >= max_retries:
        break
    attempt = 0  # Reset the attempt counter if the operation succeeds
    for _ in range(max_retries):
        attempt += 1
        try:
            chunk = word_list[i:i+batch_size]
            rarity_prompt = get_prompt_for_rarity_classification(chunk)
            sample_response_translation = get_completion( prompt=rarity_prompt, model="gpt-4o-mini" , temperature=temp)
            content = sample_response_translation.choices[0].message.content
            word_rarity_df = parse_translation_response(content)
            all_dfs.append(word_rarity_df) 
            break  # If the task succeeds, move on to the next item
        except Exception as e:
            print(f"Attempt {attempt} failed for {chunk}: {e}")
            if attempt < max_retries :
                time.sleep(1)  # Optional: Wait for 1 second before retrying
            else:
                print(f"Exceed Maximum Retries for {chunk}")
# Out:
# 100%|██████████| 108/108 [01:36<00:00,  1.12it/s]

# %%
df_result = pd.concat(all_dfs)
df_result['Word Rarity'].value_counts()

df_merge = df.merge(df_result.rename(columns={'Word Rarity': 'Rarity2'}), on='Word', how='left')
df_merge['Word Rarity'] = np.where(df_merge['Word Rarity'] == "", df_merge['Rarity2'], df_merge['Word Rarity'])
# Out:
# Common    509
# Rare       27
# Name: Word Rarity, dtype: int64

# %%
#save_df_to_gsheet(gsheet_name, dict_sheet_name, df_merge, overwrite_mode=True)

# %% [markdown]
# ## Prompt Mentoring

# %%
client = OpenAI(api_key="<Insert yours>")

equality_statement = "Interprete this 'Edge_PB_Share_Avg > 0.82', 'EnterpriseMobilityCoreE3Rev > 1907.40', '5921.00 < AADPAllUp_MAU <= 15701.50',"

def interpret_equality_statement(equality_statement):
    # Initialize variables for tracking attempts
    attempt_count = 0
    max_attempts = 5
    highest_score = 0
    feedback_dict = {}
 
    while attempt_count < max_attempts:
        # MLS Simulation: Generate interpretation
        interpretation = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {
                    "role": "system",
                    "content": """You are a Machine Learning Scientist who converts equality statements into proper English.
                        An equality statement has the pattern "<measure> <equality> <value>" or "<value> <equality> <measure> <equality> <value>".

                        <measure> has a mapping to proper English:
                        Edge_PB_Share_Avg : Edge Primary Browser Share
                        SPO_MAU : SharePoint Online MAU
                        EnterpriseMobilityCoreE3Rev : EMS E3 Revenue
                        AADPAllUp_MAU : Entra ID MAU

                        if <value> is less than 1, it is a percentage.
                        if <value> is greater than 999, it must have comma(s).
                        if <value> is greater than 1, it must be rounded to the nearest whole number.
                        if <measure> has MAU, round <value> to the nearest hundred.

                        You always start an English sentence with the phrase "We recommend this product for this tenant because..."

                    """
                },
                {
                    "role": "user",
                    "content": equality_statement
                }
            ]
        )
        generated_interpretation = interpretation.choices[0].message.content

        # Mentor Simulation: Generate mentor feedback
        mentor_feedback = client.chat.completions.create(
            model="gpt-4",
            messages=[
                {
                    "role": "system",
                    "content": """You are a senior leader in an organization who evaluates the output of the Machine Learning Scientist. You will give them a score of their work from 1 to 10, and provide reasons and comments.

                        Evaluation criteria:
                        1. The equality statement should have the pattern "<measure> <equality> <value>" or "<value> <equality> <measure> <equality> <value>".
                        2. The statement needs to be mapped to proper English:
                            - Edge_PB_Share_Avg: Edge Primary Browser Share
                            - SPO_MAU: SharePoint Online MAU
                            - EnterpriseMobilityCoreE3Rev: EMS E3 Revenue
                            - AADPAllUp_MAU: Entra ID MAU
                        3. If <value> is less than 1, it's a percentage.
                        4. If <value> is greater than 999, it should have commas.
                        5. If <value> is greater than 1, round to the nearest whole number.
                        6. If the <measure> has MAU, round the <value> to the nearest hundred.
                        7. The English sentence should always start with the phrase "We recommend this product for this tenant because...".
                        8. The response should be in professional English.
                        9. Your mentee should not say the result is rounded or anything related to how they finish the process in the response, they should stick with the precise interpretation

                        # Good Examples:
                        Sharepoint Online usage is above 80%
                        Azure Revenue is more than $1000
                        the Entra ID MAU is between 5,900 and 15,700

                        # Bad Examples:
                        the Entrta ID MAU is between 5921 and 15701, rounded to the nearest hundred

                     Sample output: Score: 8.5; Comments: This is good. You missed the SPO_MAU : SharePoint Online MAU converter
                    This is just a sample output, you don't have to follow 100%, but think and give your feedback, if there is no mistake, you can give a 10 as well!
                    But you need to strictly follow the sample output format with Score:<your score, one number or float>; Comments:< Your comments>  
                    """
                },
                {
                    "role": "user",
                    "content": f"Evaluate this work and provide a score and comment.\nOriginal equality statement: {equality_statement}\nWork: {generated_interpretation}"
                }
            ]
        )

        # Parse mentor's feedback
        mentor_response = mentor_feedback.choices[0].message.content
        score = float(mentor_response.split('Score: ')[1].split(';')[0])
        comment = mentor_response.split('Comments: ')[1]
 
        # Check if the score is acceptable
        if score >= 8.5:
            return f"Interpretation Approved: {generated_interpretation}"
 
        # If score is below 8.5, store the feedback
        feedback_dict[attempt_count] = {'score': score, 'comment': comment}
        highest_score = max(highest_score, score)

        # Output feedback and ask user to revise with mentor's comment attached
        print(f"Attempt {attempt_count + 1}: Score: {score}, Feedback: {comment}")
        equality_statement = input(f"Please revise your equality statement based on the mentor's feedback:\n{comment}\nYour revised statement: ")

        attempt_count += 1
 
    # If the loop ends without a passing score, output the highest score
    return f"Max attempts reached. Highest score: {highest_score}, Feedback from last attempt: {feedback_dict[attempt_count-1]['comment']}"


# Example usage
result = interpret_equality_statement("Interprete this 'Edge_PB_Share_Avg > 0.82', 'EnterpriseMobilityCoreE3Rev > 1907.40', '5921.00 < AADPAllUp_MAU <= 15701.50' to english")
print(result)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[69], line 112
#     108     return f"Max attempts reached. Highest score: {highest_score}, Feedback from last attempt: {feedback_dict[attempt_count-1]['comment']}"
#     111 # Example usage
# --> 112 result = interpret_equality_statement("Interprete this 'Edge_PB_Share_Avg > 0.82', 'EnterpriseMobilityCoreE3Rev > 1907.40', '5921.00 < AADPAllUp_MAU <= 15701.50' to english")
#     113 print(result)
#
# Cell In[69], line 14, in interpret_equality_statement(equality_statement)
#      10 feedback_dict = {}
#      12 while attempt_count < max_attempts:
#      13     # MLS Simulation: Generate interpretation
# ---> 14     interpretation = client.chat.completions.create(
#      15         model="gpt-4o-mini",
#      16         messages=[
#      17             {
#      18                 "role": "system",
#      19                 "content": """You are a Machine Learning Scientist who converts equality statements into proper English.
#      20                     An equality statement has the pattern "<measure> <equality> <value>" or "<value> <equality> <measure> <equality> <value>".
#      21
#      22                     <measure> has a mapping to proper English:
#      23                     Edge_PB_Share_Avg : Edge Primary Browser Share
#      24                     SPO_MAU : SharePoint Online MAU
#      25                     EnterpriseMobilityCoreE3Rev : EMS E3 Revenue
#      26                     AADPAllUp_MAU : Entra ID MAU
#      27
#      28                     if <value> is less than 1, it is a percentage.
#      29                     if <value> is greater than 999, it must have comma(s).
#      30                     if <value> is greater than 1, it must be rounded to the nearest whole number.
#      31                     if <measure> has MAU, round <value> to the nearest hundred.
#      32
#      33                     You always start an English sentence with the phrase "We recommend this product for this tenant because..."
#      34
#      35                 """
#      36             },
#      37             {
#      38                 "role": "user",
#      39                 "content": equality_statement
#      40             }
#      41         ]
#      42     )
#      43     generated_interpretation = interpretation.choices[0].message.content
#      45     # Mentor Simulation: Generate mentor feedback
#
# File c:\Users\wongs\anaconda3\lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File c:\Users\wongs\anaconda3\lib\site-packages\openai\resources\chat\completions.py:663, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     611 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     612 def create(
#     613     self,
#    (...)
#     661     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     662 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 663     return self._post(
#     664         "/chat/completions",
#     665         body=maybe_transform(
#     666             {
#     667                 "messages": messages,
#     668                 "model": model,
#     669                 "frequency_penalty": frequency_penalty,
#     670                 "function_call": function_call,
#     671                 "functions": functions,
#     672                 "logit_bias": logit_bias,
#     673                 "logprobs": logprobs,
#     674                 "max_tokens": max_tokens,
#     675                 "n": n,
#     676                 "presence_penalty": presence_penalty,
#     677                 "response_format": response_format,
#     678                 "seed": seed,
#     679                 "stop": stop,
#     680                 "stream": stream,
#     681                 "temperature": temperature,
#     682                 "tool_choice": tool_choice,
#     683                 "tools": tools,
#     684                 "top_logprobs": top_logprobs,
#     685                 "top_p": top_p,
#     686                 "user": user,
#     687             },
#     688             completion_create_params.CompletionCreateParams,
#     689         ),
#     690         options=make_request_options(
#     691             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     692         ),
#     693         cast_to=ChatCompletion,
#     694         stream=stream or False,
#     695         stream_cls=Stream[ChatCompletionChunk],
#     696     )
#
# File c:\Users\wongs\anaconda3\lib\site-packages\openai\_base_client.py:1200, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1186 def post(
#    1187     self,
#    1188     path: str,
#    (...)
#    1195     stream_cls: type[_StreamT] | None = None,
#    1196 ) -> ResponseT | _StreamT:
#    1197     opts = FinalRequestOptions.construct(
#    1198         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1199     )
# -> 1200     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\wongs\anaconda3\lib\site-packages\openai\_base_client.py:889, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     880 def request(
#     881     self,
#     882     cast_to: Type[ResponseT],
#    (...)
#     887     stream_cls: type[_StreamT] | None = None,
#     888 ) -> ResponseT | _StreamT:
# --> 889     return self._request(
#     890         cast_to=cast_to,
#     891         options=options,
#     892         stream=stream,
#     893         stream_cls=stream_cls,
#     894         remaining_retries=remaining_retries,
#     895     )
#
# File c:\Users\wongs\anaconda3\lib\site-packages\openai\_base_client.py:980, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     977         err.response.read()
#     979     log.debug("Re-raising status error")
# --> 980     raise self._make_status_error_from_response(err.response) from None
#     982 return self._process_response(
#     983     cast_to=cast_to,
#     984     options=options,
#    (...)
#     987     stream_cls=stream_cls,
#     988 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: <Insert **urs>. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
